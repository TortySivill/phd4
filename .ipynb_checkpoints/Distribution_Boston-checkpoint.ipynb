# %%
import gately
import shapley
import numpy as np
import random
import timeit
import shap

# %%
#X, y = shap.datasets.nhanesi()

# %%
X, y = shap.datasets.iris()
X = X.values

# %%
X.shape
# Out:
# (150, 4)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import xgboost

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

regr = xgboost.XGBRegressor().fit(X_train, y_train)
regr.fit(X_train, y_train)
regr.score(X_test,y_test)
# Out:
# 0.8625046942587472

# %%
X_train.shape
# Out:
# (90, 4)

# %%
att_shap, dist_shap = shapley.shapley_int_distribution(regr.predict,X_test[0],X_test[1])

# %%
att_shap
# Out:
# {0: array([0.], dtype=float32),
#  1: array([9.9438905e-05], dtype=float32),
#  2: array([0.99974567], dtype=float32),
#  3: array([0.], dtype=float32)}

# %%
att_gately, dist_gately = gately.Gately_distribution(X_test[0],X_test[1],regr.predict)

# %%
att_gately
# Out:
# {0: array([0.], dtype=float32),
#  1: array([9.942055e-05], dtype=float32),
#  2: array([0.9997455], dtype=float32),
#  3: array([0.], dtype=float32)}

# %%
X_test[0].shape
# Out:
# (4,)

# %%
matches = 0
distributions_shap = []
distributions_gately = []
for ind in range(0,20):
    att_shap, dist_shap = shapley.shapley_int_distribution(regr.predict,X_test[ind],X_test[ind+1])
    att_gately, dist_gately = gately.Gately_distribution(X_test[ind],X_test[ind+1],regr.predict)

    tick = 0
    for i,j in zip(att_shap.values(),att_gately.values()):
        if round(i[0],2) != round(j[0],2):
            tick = 1
    if tick == 0:
        matches += 1
    
    distributions_shap.append(dist_shap)
    distributions_gately.append(dist_gately)
        
distributions_shap = np.asarray(distributions_shap)
distributions_gately = np.asarray(distributions_gately)
#print(distributions_shap.shape)
#distributions_shap = distributions_shap.reshape(-1,distributions_shap.shape[2])
distributions_gately = distributions_gately.reshape(-1,distributions_gately.shape[2])
# Out:
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
samples = X.copy()

# %%
scores_gately = []
scores_shap = []

for i in range(1,100):
    X = np.concatenate([distributions_gately[0:100],samples[0:100]])
    Y = np.concatenate([np.zeros(100),np.ones(100)])
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.model_selection import train_test_split

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

    regr = RandomForestClassifier(n_estimators=i, random_state=0)
    regr.fit(X_train, y_train)
    scores_gately.append(regr.score(X_test,y_test))

    X = np.concatenate([distributions_shap[0][0:100],samples[0:100]])
    Y = np.concatenate([np.zeros(100),np.ones(100)])

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

    regr = RandomForestClassifier(n_estimators=i, random_state=0)
    regr.fit(X_train, y_train)
    scores_shap.append(regr.score(X_test,y_test))

# %%
import matplotlib.pyplot as plt

depth = np.arange(1,100)
plt.plot(depth, scores_gately)
plt.plot(depth, scores_shap)
plt.xlabel('Number of Trees')
plt.ylabel('Random Forest Model Accuracy')

plt.savefig('distribution.pdf')

# %%
X = np.concatenate([distributions_shap[0:140],datas[0:140]])
Y = np.concatenate([np.zeros(140),np.ones(140)])
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

regr = RandomForestClassifier(max_depth=1, random_state=0)
regr.fit(X_train, y_train)
regr.score(X_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 X = np.concatenate([distributions_shap[0:140],datas[0:140]])
#       2 Y = np.concatenate([np.zeros(140),np.ones(140)])
#       3 from sklearn.ensemble import RandomForestClassifier
#
# NameError: name 'datas' is not defined
